# %%
import pandas as pd
import numpy as np

# %%
#help(pd.read_csv)

# %%
df = pd.read_csv('examples/ex1.csv')
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_table('examples/ex1.csv')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a,b,c,d,message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1,2,3,4,hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5,6,7,8,world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9,10,11,12,foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_table('examples/ex1.csv', sep=',')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_csv('examples/ex2.csv', header=None)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_csv('examples/ex2.csv', names=['a', 'b', 'c', 'd', 'message'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv('examples/ex2.csv', names=names, index_col='message')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#     <tr>
#       <th>message</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>hello</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>world</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>foo</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
parsed = pd.read_csv('examples/csv_mindex.csv', index_col=['key1', 'key2'])
parsed
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>value1</th>
#       <th>value2</th>
#     </tr>
#     <tr>
#       <th>key1</th>
#       <th>key2</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="4" valign="top">one</th>
#       <th>a</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>b</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>c</th>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>d</th>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th rowspan="4" valign="top">two</th>
# ...

# %%
list(open('examples/ex3.txt'))
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491\n']

# %%
result = pd.read_table('examples/ex3.txt', sep='\s+')
# \s+ uses whitespace to figure out where the line ends
result
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>aaa</th>
#       <td>-0.264438</td>
#       <td>-1.026059</td>
#       <td>-0.619500</td>
#     </tr>
#     <tr>
#       <th>bbb</th>
#       <td>0.927272</td>
#       <td>0.302904</td>
#       <td>-0.032399</td>
#     </tr>
#     <tr>
#       <th>ccc</th>
#       <td>-0.264273</td>
#       <td>-0.386314</td>
#       <td>-0.217601</td>
#     </tr>
#     <tr>
#       <th>ddd</th>
#       <td>-0.871858</td>
#       <td>-0.348382</td>
#       <td>1.100491</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
list(open('examples/ex4.csv'))
# Out:
# ['# hey!\n',
#  'a,b,c,d,message\n',
#  '# just wanted to make things more difficult for you\n',
#  '# who reads CSV files with computers, anyway?\n',
#  '1,2,3,4,hello\n',
#  '5,6,7,8,world\n',
#  '9,10,11,12,foo']

# %%
pd.read_csv('examples/ex4.csv', skiprows=[0, 2, 3])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.options.display.max_rows = 10
result = pd.read_csv('examples/ex6.csv')
result
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.467976</td>
#       <td>-0.038649</td>
#       <td>-0.295344</td>
#       <td>-1.824726</td>
#       <td>L</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-0.358893</td>
#       <td>1.404453</td>
#       <td>0.704965</td>
#       <td>-0.200638</td>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-0.501840</td>
#       <td>0.659254</td>
#       <td>-0.421691</td>
#       <td>-0.057688</td>
#       <td>G</td>
# ...

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=1000)

tot = pd.Series([])
for piece in chunker:
    tot = tot.add(piece['key'].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)

tot[:10]
# Out:
# E    368.0
# X    364.0
# L    346.0
# O    343.0
# Q    340.0
# M    338.0
# J    337.0
# F    335.0
# K    334.0
# H    330.0
# dtype: float64

# %%
data = pd.read_csv('examples/ex5.csv')

# %%
data.to_csv('examples/out.csv')

# %%
list(open('examples/out.csv'))
# Out:
# [',something,a,b,c,d,message\n',
#  '0,one,1,2,3.0,4,\n',
#  '1,two,5,6,,8,world\n',
#  '2,three,9,10,11.0,12,foo\n']

# %%
import sys

# %%
data.to_csv(sys.stdout, sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %%
data.to_csv(sys.stdout, na_rep='NULL', sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|NULL
# 1|two|5|6|NULL|8|world
# 2|three|9|10|11.0|12|foo

# %%
import csv

# %%
class my_dialect(csv.Dialect):
    lineterminator = '\n'
    delimiter = ';'
    quotechar = '"'
    quoting = csv.QUOTE_MINIMAL

# %%
with open('mydata.csv', 'w') as f:
    writer = csv.writer(f, dialect=my_dialect)
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# %%
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
{"name": "Katie", "age": 38,
"pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json

# %%
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Scott</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Katie</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data = pd.read_json('examples/example.json')
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7</td>
#       <td>8</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}

# %%
print(data.to_json('examples/example_json_2.json'))
# Out:
# None

# %%
from lxml import objectify

# %%
path = 'examples/mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ', 'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>AGENCY_NAME</th>
#       <th>CATEGORY</th>
#       <th>DESCRIPTION</th>
#       <th>FREQUENCY</th>
#       <th>INDICATOR_NAME</th>
#       <th>INDICATOR_UNIT</th>
#       <th>MONTHLY_ACTUAL</th>
#       <th>MONTHLY_TARGET</th>
#       <th>PERIOD_MONTH</th>
#       <th>PERIOD_YEAR</th>
#       <th>YTD_ACTUAL</th>
#       <th>YTD_TARGET</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Metro-North Railroad</td>
#       <td>Service Indicators</td>
#       <td>Percent of commuter trains that arrive at thei...</td>
#       <td>M</td>
#       <td>On-Time Performance (West of Hudson)</td>
# ...

# %%
frame = pd.read_csv('examples/ex1.csv')
frame
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame.to_pickle('examples/frame_pickle')

# %%
pd.read_pickle('examples/frame_pickle')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# “Pickling” is the process whereby a Python object hierarchy is converted into a byte stream,
# <br/>and “unpickling” is the inverse operation, whereby a byte stream (from a binary file or bytes-like object)
# <br/>is converted back into an object hierarchy.

# %% [markdown]
# pickle is only recommended as a short-term storage format. The problem is that it is hard to
# <br/>guarantee that the format will be stable over time; an object pickled today may not unpickle
# <br/>with a later version of a library. We have tried to maintain backward compatibility when
# <br/>possible, but at some point in the future it may be necessary to “break” the pickle format.

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5
# /obj1                frame        (shape->[100,1])
# /obj1_col            series       (shape->[100])

# %%
store.put('obj2', frame, format='table')

# %%
store.select('obj2', where=['index >= 10 and index <= 15'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10</th>
#       <td>-0.936503</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.608408</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>-0.456377</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>-1.333528</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>-0.597507</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.203544</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')

# %%
pd.read_excel(xlsx, 'Sheet1')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_excel('examples/ex1.xlsx', 'Sheet1')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
frame = pd.read_excel('examples/ex1.xlsx', 'Sheet1')

# %% [markdown]
# the first method is better for spreadsheets with multiple tabs

# %%
writer = pd.ExcelWriter('examples/ex2.xlsx')

# %%
frame.to_excel(writer, 'Sheet1')

# %%
writer.save()

# %%
writer.close()

# %%
xlsx2 = pd.ExcelFile('examples/ex2.xlsx')

# %%
pd.read_excel(xlsx2, 'Sheet1')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#       <th>message</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#       <td>hello</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#       <td>world</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#       <td>12</td>
#       <td>foo</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
data = resp.json()
data[0]['title']
# Out:
# 'COMPAT: IntegerXXDtypes string repr cause numpy deprecation warnings'

# %%
issues = pd.DataFrame(data, columns=['number', 'title', 'labels', 'state'])
issues
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>number</th>
#       <th>title</th>
#       <th>labels</th>
#       <th>state</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>24593</td>
#       <td>COMPAT: IntegerXXDtypes string repr cause nump...</td>
#       <td>[]</td>
#       <td>open</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>24592</td>
#       <td>Groupby(observed=False) behaviour does not fol...</td>
#       <td>[]</td>
#       <td>open</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>24590</td>
#       <td>DOC: Bump fastparquet version</td>
#       <td>[{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...</td>
# ...

# %%
import sqlite3

# %%
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
c REAL, d INTEGER
);"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6), ('Tallahassee', 'Florida', 2.6, 3), ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#       <th>b</th>
#       <th>c</th>
#       <th>d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Atlanta</td>
#       <td>Georgia</td>
#       <td>1.25</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Tallahassee</td>
#       <td>Florida</td>
#       <td>2.60</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sacramento</td>
#       <td>California</td>
#       <td>1.70</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>
