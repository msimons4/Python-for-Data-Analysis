# %%
import pandas as pd
import numpy as np

# %%
string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])
string_data
# Out:
# 0     aardvark
# 1    artichoke
# 2          NaN
# 3      avocado
# dtype: object

# %%
string_data.fillna(method='ffill')
# Out:
# 0     aardvark
# 1    artichoke
# 2    artichoke
# 3      avocado
# dtype: object

# %%
string_data.fillna(method='bfill')
# Out:
# 0     aardvark
# 1    artichoke
# 2      avocado
# 3      avocado
# dtype: object

# %%
from numpy import nan as NA

# %%
data = pd.Series([1, NA, 3.5, NA, 7])
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %% [markdown]
# in a DataFrame dropna by default drops any row containing a missing value

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA], [NA, NA, NA], [NA, 6.5, 3.]])
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cleaned = data.dropna()
cleaned
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
new_cleaned = data.dropna(how='all') # this removes rows that are all NA
new_cleaned
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data[4] = NA
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
second_new_data = data.dropna(axis=1, how='all')
second_new_data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>6.5</td>
#       <td>3.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.DataFrame(np.random.randn(7, 3))
df.iloc[:4, 1] = NA
df.iloc[:2, 2] = NA
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.225726</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.337942</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.923801</td>
#       <td>NaN</td>
#       <td>1.044298</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.781936</td>
#       <td>NaN</td>
#       <td>-1.105966</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.039248</td>
#       <td>-0.315860</td>
# ...

# %%
df.fillna(0)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.861543</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.241131</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.330944</td>
#       <td>0.000000</td>
#       <td>-0.520355</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.134768</td>
#       <td>0.000000</td>
#       <td>1.002004</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.616273</td>
# ...

# %%
df.fillna({1: 0.5, 2: 0})
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.861543</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.241131</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.330944</td>
#       <td>0.500000</td>
#       <td>-0.520355</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.134768</td>
#       <td>0.500000</td>
#       <td>1.002004</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.616273</td>
# ...

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-1.861543</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.241131</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.330944</td>
#       <td>NaN</td>
#       <td>-0.520355</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.134768</td>
#       <td>NaN</td>
#       <td>1.002004</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-0.616273</td>
#       <td>-1.302586</td>
# ...

# %%
_ = df.fillna(0, inplace=True) # using inplace changes the actual DF rather than just making a cooy

# %%
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>-0.225726</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.337942</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.923801</td>
#       <td>0.000000</td>
#       <td>1.044298</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.781936</td>
#       <td>0.000000</td>
#       <td>-1.105966</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.039248</td>
# ...

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df.iloc[2:, 1] = NA
df.iloc[4:, 2] = NA
df
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.815810</td>
#       <td>1.23365</td>
#       <td>0.898576</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.034848</td>
#       <td>-0.93857</td>
#       <td>-0.626979</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.623798</td>
#       <td>NaN</td>
#       <td>-0.918069</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.367553</td>
#       <td>NaN</td>
#       <td>-0.379504</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-1.381436</td>
#       <td>NaN</td>
# ...

# %%
df.fillna(method='ffill')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.815810</td>
#       <td>1.23365</td>
#       <td>0.898576</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.034848</td>
#       <td>-0.93857</td>
#       <td>-0.626979</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.623798</td>
#       <td>-0.93857</td>
#       <td>-0.918069</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.367553</td>
#       <td>-0.93857</td>
#       <td>-0.379504</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-1.381436</td>
# ...

# %%
df.fillna(method='ffill', limit=2)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.815810</td>
#       <td>1.23365</td>
#       <td>0.898576</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.034848</td>
#       <td>-0.93857</td>
#       <td>-0.626979</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.623798</td>
#       <td>-0.93857</td>
#       <td>-0.918069</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>-0.367553</td>
#       <td>-0.93857</td>
#       <td>-0.379504</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>-1.381436</td>
# ...

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'], 'k2': [1, 1, 2, 3, 3, 4, 4]})
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>two</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>two</td>
#       <td>4</td>
# ...

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
data.drop_duplicates()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>two</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>two</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data['v1'] = range(7)
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#       <th>v1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>two</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
data.drop_duplicates(['k1'])
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#       <th>v1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.drop_duplicates(['k1'], keep='last')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>k1</th>
#       <th>k2</th>
#       <th>v1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4</th>
#       <td>one</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>two</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami', 'corned beef', 'Bacon', 'pastrami', 'honey ham', 'nova lox'], 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>food</th>
#       <th>ounces</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bacon</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>pulled pork</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>bacon</td>
#       <td>12.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Pastrami</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>corned beef</td>
#       <td>7.5</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Bacon</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
# ...

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'honey ham': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'nova lox': 'salmon'
}

# %%
lowercased = data['food'].str.lower()
lowercased
# Out:
# 0          bacon
# 1    pulled pork
# 2          bacon
# 3       pastrami
# 4    corned beef
# 5          bacon
# 6       pastrami
# 7      honey ham
# 8       nova lox
# Name: food, dtype: object

# %%
data['animal'] = lowercased.map(meat_to_animal)
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>food</th>
#       <th>ounces</th>
#       <th>animal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bacon</td>
#       <td>4.0</td>
#       <td>pig</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>pulled pork</td>
#       <td>3.0</td>
#       <td>pig</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>bacon</td>
#       <td>12.0</td>
#       <td>pig</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Pastrami</td>
#       <td>6.0</td>
#       <td>cow</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>corned beef</td>
#       <td>7.5</td>
#       <td>cow</td>
# ...

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, -9)
# Out:
# 0       1.0
# 1      -9.0
# 2       2.0
# 3      -9.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], [-9, -1])
# Out:
# 0    1.0
# 1   -9.0
# 2    2.0
# 3   -9.0
# 4   -1.0
# 5    3.0
# dtype: float64

# %%
data.replace({-999: -9, -1000: -1})
# Out:
# 0    1.0
# 1   -9.0
# 2    2.0
# 3   -9.0
# 4   -1.0
# 5    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)), index=['Ohio', 'Colorado', 'New York'], columns=['one', 'two', 'three', 'four'])
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ohio</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Colorado</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>New York</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
transform = lambda x: x[:4].upper()
data.index = data.index.map(transform)
data
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>three</th>
#       <th>four</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>OHIO</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>COLO</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>NEW</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.rename(columns=transform, index=str.title)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ONE</th>
#       <th>TWO</th>
#       <th>THRE</th>
#       <th>FOUR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Ohio</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Colo</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>New</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.rename(index={'OHIO': 'INDIANA'}, columns={'three': 'peekaboo'})
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>one</th>
#       <th>two</th>
#       <th>peekaboo</th>
#       <th>four</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>INDIANA</th>
#       <td>0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>COLO</th>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>NEW</th>
#       <td>8</td>
#       <td>9</td>
#       <td>10</td>
#       <td>11</td>
#     </tr>
#   </tbody>
# </table>
# </div>
